# %% [markdown]
# <a href="https://colab.research.google.com/github/Najila-1234/framingham_pca/blob/main/framingham_pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/framingham.csv')
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df=df.drop(['education'],axis=1)
df
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4235     0   48              1        20.0     NaN                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# ...

# %%
df['cigsPerDay']=df['cigsPerDay'].fillna((df['cigsPerDay']).mode()[0])
df['BPMeds']=df['BPMeds'].fillna((df['BPMeds']).mean())
df['BMI']=df['BMI'].fillna((df['BMI']).mean())
df['totChol']=df['totChol'].fillna((df['totChol']).mean())
df['glucose']=df['glucose'].fillna((df['glucose']).mean())
df['heartRate']=df['heartRate'].fillna((df['heartRate']).mean())

# %%
df.isna().sum()
# Out:
# male               0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
# do scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.15311332, -1.23428297, -0.98827627, ...,  0.28725796,
#          0.34277523, -0.21742709],
#        [-0.86721746, -0.41766419, -0.98827627, ...,  0.71966845,
#          1.59043467, -0.26123092],
#        [ 1.15311332, -0.18434454,  1.01186281, ..., -0.11321311,
#         -0.07311125, -0.52405388],
#        ...,
#        [-0.86721746,  0.28229477, -0.98827627, ..., -1.06402482,
#          0.34277523,  1.09668771],
#        [ 1.15311332, -1.11762315, -0.98827627, ..., -0.04933429,
#         -0.73852962, -0.43644623],
#        [-0.86721746, -1.23428297,  1.01186281, ..., -1.20160997,
#          0.75866171, -0.08601561]])

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=10)
x=pca.fit_transform(x)
x
# Out:
# array([[-1.59843752, -0.97231984,  0.06946436, ...,  0.82358151,
#          1.16422781,  0.44447535],
#        [-0.01595612, -1.24452997, -0.22021297, ...,  1.03387271,
#          0.5212117 , -0.20076436],
#        [-1.12248983,  1.41052429, -0.16000989, ...,  0.21306749,
#          0.33766702,  0.10177828],
#        ...,
#        [ 0.1594171 , -1.51091281,  0.61345737, ..., -0.41401702,
#          0.16878008,  0.66689321],
#        [ 0.8904635 , -0.09695176, -0.86784283, ..., -0.65307057,
#         -0.02951298,  1.381402  ],
#        [-1.48681794,  1.52854399,  0.0542905 , ..., -0.69438606,
#         -0.53813186,  0.11748615]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8388364779874213

# %%
pca.explained_variance_ratio_  # 22 percent information is available in first feature
# Out:
# array([0.22624167, 0.13384605, 0.11124837, 0.08087182, 0.07618825,
#        0.07360162, 0.06286237, 0.0574133 , 0.04898091, 0.04463612])
